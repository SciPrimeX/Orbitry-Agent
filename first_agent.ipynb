# %%
! pip install --upgrade langchain langchain-google-genai
# Out:
# Requirement already satisfied: langchain in /Users/alexxela/.pyenv/versions/3.12.9/envs/langchain-env/lib/python3.12/site-packages (1.1.0)
# Collecting langchain
#   Downloading langchain-1.2.6-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: langchain-google-genai in /Users/alexxela/.pyenv/versions/3.12.9/envs/langchain-env/lib/python3.12/site-packages (3.0.2)
# Collecting langchain-google-genai
#   Downloading langchain_google_genai-4.2.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting langchain-core<2.0.0,>=1.2.7 (from langchain)
#   Downloading langchain_core-1.2.7-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.2 in /Users/alexxela/.pyenv/versions/3.12.9/envs/langchain-env/lib/python3.12/site-packages (from langchain) (1.0.3)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/alexxela/.pyenv/versions/3.12.9/envs/langchain-env/lib/python3.12/site-packages (from langchain) (2.12.4)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Users/alexxela/.pyenv/versions/3.12.9/envs/langchain-env/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.2.7->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /Users/alexxela/.pyenv/versions/3.12.9/envs/langchain-env/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.2.7->langchain) (0.4.42)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /Users/alexxela/.pyenv/versions/3.12.9/envs/langchain-env/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.2.7->langchain) (24.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /Users/alexxela/.pyenv/versions/3.12.9/envs/langchain-env/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.2.7->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/alexxela/.pyenv/versions/3.12.9/envs/langchain-env/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.2.7->langchain) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /Users/alexxela/.pyenv/versions/3.12.9/envs/langchain-env/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.2.7->langchain) (4.15.0)
# Collecting uuid-utils<1.0,>=0.12.0 (from langchain-core<2.0.0,>=1.2.7->langchain)
#   Downloading uuid_utils-0.14.0-cp39-abi3-macosx_10_12_x86_64.macosx_11_0_arm64.macosx_10_12_universal2.whl.metadata (4.9 kB)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/alexxela/.pyenv/versions/3.12.9/envs/langchain-env/lib/python3.12/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.7->langchain) (3.0.0)
# Requirement already satisfied: langgraph-checkpoint<4.0.0,>=2.1.0 in /Users/alexxela/.pyenv/versions/3.12.9/envs/langchain-env/lib/python3.12/site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (2.1.2)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in /Users/alexxela/.pyenv/versions/3.12.9/envs/langchain-env/lib/python3.12/site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (1.0.2)
# Requirement already satisfied: langgraph-sdk<0.3.0,>=0.2.2 in /Users/alexxela/.pyenv/versions/3.12.9/envs/langchain-env/lib/python3.12/site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (0.2.9)
# Requirement already satisfied: xxhash>=3.5.0 in /Users/alexxela/.pyenv/versions/3.12.9/envs/langchain-env/lib/python3.12/site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.10.0 in /Users/alexxela/.pyenv/versions/3.12.9/envs/langchain-env/lib/python3.12/site-packages (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain) (1.12.0)
# Requirement already satisfied: httpx>=0.25.2 in /Users/alexxela/.pyenv/versions/3.12.9/envs/langchain-env/lib/python3.12/site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in /Users/alexxela/.pyenv/versions/3.12.9/envs/langchain-env/lib/python3.12/site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/alexxela/.pyenv/versions/3.12.9/envs/langchain-env/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.7->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /Users/alexxela/.pyenv/versions/3.12.9/envs/langchain-env/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.7->langchain) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/alexxela/.pyenv/versions/3.12.9/envs/langchain-env/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.7->langchain) (0.23.0)
# Requirement already satisfied: anyio in /Users/alexxela/.pyenv/versions/3.12.9/envs/langchain-env/lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (4.11.0)
# Requirement already satisfied: certifi in /Users/alexxela/.pyenv/versions/3.12.9/envs/langchain-env/lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /Users/alexxela/.pyenv/versions/3.12.9/envs/langchain-env/lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (1.0.9)
# Requirement already satisfied: idna in /Users/alexxela/.pyenv/versions/3.12.9/envs/langchain-env/lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/alexxela/.pyenv/versions/3.12.9/envs/langchain-env/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/alexxela/.pyenv/versions/3.12.9/envs/langchain-env/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/alexxela/.pyenv/versions/3.12.9/envs/langchain-env/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/alexxela/.pyenv/versions/3.12.9/envs/langchain-env/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /Users/alexxela/.pyenv/versions/3.12.9/envs/langchain-env/lib/python3.12/site-packages (from langchain-google-genai) (1.2.0)
# Collecting google-genai<2.0.0,>=1.56.0 (from langchain-google-genai)
#   Downloading google_genai-1.59.0-py3-none-any.whl.metadata (53 kB)
# Collecting google-auth<3.0.0,>=2.47.0 (from google-auth[requests]<3.0.0,>=2.47.0->google-genai<2.0.0,>=1.56.0->langchain-google-genai)
#   Downloading google_auth-2.47.0-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: websockets<15.1.0,>=13.0.0 in /Users/alexxela/.pyenv/versions/3.12.9/envs/langchain-env/lib/python3.12/site-packages (from google-genai<2.0.0,>=1.56.0->langchain-google-genai) (15.0.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/alexxela/.pyenv/versions/3.12.9/envs/langchain-env/lib/python3.12/site-packages (from google-genai<2.0.0,>=1.56.0->langchain-google-genai) (1.9.0)
# Requirement already satisfied: sniffio in /Users/alexxela/.pyenv/versions/3.12.9/envs/langchain-env/lib/python3.12/site-packages (from google-genai<2.0.0,>=1.56.0->langchain-google-genai) (1.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/alexxela/.pyenv/versions/3.12.9/envs/langchain-env/lib/python3.12/site-packages (from google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/alexxela/.pyenv/versions/3.12.9/envs/langchain-env/lib/python3.12/site-packages (from google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (4.9.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/alexxela/.pyenv/versions/3.12.9/envs/langchain-env/lib/python3.12/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.7->langchain) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/alexxela/.pyenv/versions/3.12.9/envs/langchain-env/lib/python3.12/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.7->langchain) (2.3.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /Users/alexxela/.pyenv/versions/3.12.9/envs/langchain-env/lib/python3.12/site-packages (from rsa<5,>=3.1.4->google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (0.6.1)
# Downloading langchain-1.2.6-py3-none-any.whl (108 kB)
# Downloading langchain_core-1.2.7-py3-none-any.whl (490 kB)
# Downloading uuid_utils-0.14.0-cp39-abi3-macosx_10_12_x86_64.macosx_11_0_arm64.macosx_10_12_universal2.whl (601 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 601.8/601.8 kB 20.9 MB/s  0:00:00
# Downloading langchain_google_genai-4.2.0-py3-none-any.whl (66 kB)
# Downloading google_genai-1.59.0-py3-none-any.whl (719 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 719.1/719.1 kB 31.3 MB/s  0:00:00
# Downloading google_auth-2.47.0-py3-none-any.whl (234 kB)
# Installing collected packages: uuid-utils, google-auth, langchain-core, google-genai, langchain-google-genai, langchain
#   Attempting uninstall: google-auth
#     Found existing installation: google-auth 2.43.0
#     Uninstalling google-auth-2.43.0:
#       Successfully uninstalled google-auth-2.43.0
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 1.1.0
#     Uninstalling langchain-core-1.1.0:
#       Successfully uninstalled langchain-core-1.1.0
#   Attempting uninstall: google-genai0m╺━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/6 [langchain-core]
#     Found existing installation: google-genai 1.14.038;5;237m━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/6 [langchain-core]
#     Uninstalling google-genai-1.14.0:8;5;237m╺━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/6 [langchain-core]
#       Successfully uninstalled google-genai-1.14.0━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/6 [langchain-core]
#   Attempting uninstall: langchain-google-genai╺━━━━━━━━━━━━━━━━━━━ 3/6 [google-genai]
#     Found existing installation: langchain-google-genai 3.0.2;5;237m━━━━━━━━━━━━━━━━━━━ 3/6 [google-genai]
#     Uninstalling langchain-google-genai-3.0.2:5;237m╺━━━━━━━━━━━━━━━━━━━ 3/6 [google-genai]
#       Successfully uninstalled langchain-google-genai-3.0.238;5;237m━━━━━━━━━━━━━━━━━━━ 3/6 [google-genai]
#   Attempting uninstall: langchain━━━━╺━━━━━━━━━━━━━━━━━━━ 3/6 [google-genai]
#     Found existing installation: langchain 1.1.0237m╺━━━━━━━━━━━━━━━━━━━ 3/6 [google-genai]
#     Uninstalling langchain-1.1.0:━━━━╺━━━━━━━━━━━━━━━━━━━ 3/6 [google-genai]
#       Successfully uninstalled langchain-1.1.05;237m╺━━━━━━━━━━━━━━━━━━━ 3/6 [google-genai]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6 [langchain]━ 5/6 [langchain]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain-community 0.3.23 requires langchain<1.0.0,>=0.3.24, but you have langchain 1.2.6 which is incompatible.
# langchain-community 0.3.23 requires langchain-core<1.0.0,>=0.3.56, but you have langchain-core 1.2.7 which is incompatible.
# langchain-community 0.3.23 requires langsmith<0.4,>=0.1.125, but you have langsmith 0.4.42 which is incompatible.
# Successfully installed google-auth-2.47.0 google-genai-1.59.0 langchain-1.2.6 langchain-core-1.2.7 langchain-google-genai-4.2.0 uuid-utils-0.14.0

# %%
import os
from dotenv import load_dotenv

load_dotenv()  # Explicit path
from langchain.agents import create_agent
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_google_genai import GoogleGenerativeAIEmbeddings

from langchain_community.document_loaders import PyPDFLoader
from langchain_community.vectorstores import FAISS

from langchain.tools import tool
from langchain.messages import SystemMessage
from langchain_core.output_parsers import JsonOutputParser

gemini_llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash", temperature=0.1,
                                    google_api_key=os.getenv('GOOGLE_API_KEY'))
embeddings = GoogleGenerativeAIEmbeddings(model="models/text-embedding-004",
                                          google_api_key=os.getenv('GOOGLE_API_KEY'))

base_directory = "base"
files = os.listdir(base_directory)
documents = []
for file in files:
    if file.endswith(".pdf"):
        loader = PyPDFLoader(os.path.join(base_directory, file))
        documents.extend(loader.load())
vectorstore = FAISS.from_documents(documents, embeddings)

@tool
def retriever(query: str) -> str:
    """Tool that retrieves relevant documents from the vector store
    about medical connection between non-invasive features such as ECG and glucose levels.
    """
    docs = vectorstore.similarity_search(query, k=3)
    return "\n\n".join([doc.page_content for doc in docs])



from pydantic import BaseModel, Field
from typing import List
from langchain_core.output_parsers import PydanticOutputParser

# Define your response model
class AgentResponse(BaseModel):
    recommend: List[str] = Field(description="List of 2 actionable recommendations (max 10 tokens each)")
    document: str = Field(description="Name of the most relevant document PDF file")

# Create parser and get format instructions
parser = PydanticOutputParser(pydantic_object=AgentResponse)
format_instructions = parser.get_format_instructions()

system_prompt = SystemMessage(
    content=f"""
    You are a Research Analyst AI assistant.
    Use the "retriever" tool to find relevant information from the provided documents
    to answer user queries accurately and comprehensively.

    Return a dictionary in the following format:
    'recommend': a list of 2 actionable recommendations based on the retrieved information (maximum 10 tokens),
    'document': name of the most relevant document pdf file from which the information was retrieved

    {format_instructions}

    IMPORTANT: Return ONLY the JSON object, with NO markdown code blocks, NO backticks, NO extra text.
    """
)

agent = create_agent(
    model=gemini_llm,
    tools=[retriever],
    system_prompt=system_prompt
    )

# %%
format_instructions
# Out:
# 'The output should be formatted as a JSON instance that conforms to the JSON schema below.\n\nAs an example, for the schema {"properties": {"foo": {"title": "Foo", "description": "a list of strings", "type": "array", "items": {"type": "string"}}}, "required": ["foo"]}\nthe object {"foo": ["bar", "baz"]} is a well-formatted instance of the schema. The object {"properties": {"foo": ["bar", "baz"]}} is not well-formatted.\n\nHere is the output schema:\n```\n{"properties": {"recommend": {"description": "List of 2 actionable recommendations (max 10 tokens each)", "items": {"type": "string"}, "title": "Recommend", "type": "array"}, "document": {"description": "Name of the most relevant document PDF file", "title": "Document", "type": "string"}}, "required": ["recommend", "document"]}\n```'

# %%
from langchain.messages import HumanMessage
def query_to_invokable(msg: str) -> HumanMessage:
    return {'messages': [HumanMessage(content=msg)]}
query = query_to_invokable(
    "My heart is beating very fast and I feel dizzy. Can my glucose levels be the reason?"
)
response = agent.invoke(query)

# %%
response['messages'][-1].content
# Out:
# [{'type': 'text',
#   'text': '{"recommend": ["Check glucose levels", "Consult a doctor"], "document": "Health and Technology (2023) 13:145–154"}',
#   'extras': {'signature': '...'}}]

# %%
import json

try:
    final_message = response['messages'][-1].content[0]['text']
    parsed_response = json.loads(final_message)
except json.JSONDecodeError as e:
    print(f"Failed to parse JSON: {e}")
    print(f"Raw content: {final_message}")

# %%
print("HumanMessage:")
print(response['messages'][0].content)
print("AI Recommendations:")
for r in parsed_response['recommend']:
    print(f"- {r}")
# Out:
# HumanMessage:
# My heart is beating very fast and I feel dizzy. Can my glucose levels be the reason?
# AI Recommendations:
# - Check glucose levels
# - Consult a doctor
